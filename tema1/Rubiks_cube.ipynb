# %%
from pocket_cube.cube import Cube
from pocket_cube.cube import Move

# %matplotlib ipympl

# %% [markdown]
# # Creating a scrambled cube

# %%
cube = Cube("F' R U R U F' U'")

# %% [markdown]
# ## 2D Cube visualization

# %%
cube.render()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Text representation

# %%
cube.render_text()
# Out:
#   YB
#   BB
# OWRRYYOG
# GOWWROBY
#   GG
#   RW

# %% [markdown]
# ## 3D Cube visualization
#
# For an interactive view of the cube, don't forget to use `%matplotlib notebook`

# %%
cube.render3D()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Creating an unscrambled cube

# %%
cube = Cube(scrambled=False)
cube = cube.move(Move.R)
cube.render3D()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Applying moves on the cube

# %%
cube = cube.move(Move.R)
# cube = cube.move(Move.F)

# %%
cube.render3D()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cube.render3D_moves(cube.state, [Move.Fp, Move.Rp])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/skemo/Facultate/Anul4/ia/tema1/Rubiks_cube.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/skemo/Facultate/Anul4/ia/tema1/Rubiks_cube.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> cube.render3D_moves(cube.state, [Move.Fp, Move.Rp])
#
# NameError: name 'cube' is not defined
